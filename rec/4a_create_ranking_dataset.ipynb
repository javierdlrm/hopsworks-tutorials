# %%
import hopsworks

project = hopsworks.login()  # insert API Key from https://app.hopsworks.ai
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://b0636a00-6406-11ed-88f4-3779517939b7.cloud.hopsworks.ai:443/p/119

# %% [markdown]
# ## Requirements
#
# Install libraries:
#
# * **tensorflow** (version 2.9.1)

# %%
# !pip install --quiet tensorflow==2.9.1
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbconvert 7.0.0 requires jinja2>=3.0, but you have jinja2 2.11.3 which is incompatible.
# nbconvert 7.0.0 requires mistune<3,>=2.0.3, but you have mistune 0.8.4 which is incompatible.
# hsfs 3.1.0.dev1 requires markupsafe<2.1.0, but you have markupsafe 2.1.1 which is incompatible.
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip

# %% [markdown]
# ## Create Ranking Dataset
#
# In this notebook, we'll create a dataset for our ranking model. Since our dataset only consists of positive user-item interactions (transactions) we need to do negative sampling. (Otherwise our model might just recommend all items to all users.)
#
# This notebook can be run to generate both training and validation data. Please run the the notebook once, change `USE_TRAIN` below to False, and run the notebook again if you want to generate both datasets.

# %%
fs = project.get_feature_store()

feature_view = fs.get_feature_view("retrieval", version=1)

train_df, val_df, test_df, y_train, y_val, y_test = feature_view.get_train_validation_test_split(training_dataset_version=1)
# Out:
# DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
# Connected. Call `.close()` to terminate connection gracefully.

# %%
train_df["article_id"] = train_df["article_id"].astype(str) # to be deleted
val_df["article_id"] = val_df["article_id"].astype(str)
test_df["article_id"] = test_df["article_id"].astype(str)

# %%
# Repeat all cells below with both USE_TRAIN = True and USE_TRAIN = false

USE_TRAIN = False

split, df = ("train", train_df) if USE_TRAIN else ("validation", val_df)
df['article_id'] = df['article_id'].astype(str)

ds_name = f"ranking_{split}.csv"

# %% [markdown]
# These are the true positive pairs.

# %%
query_features = ["customer_id", "age", "month_sin", "month_cos"]

positive_pairs = df[query_features + ["article_id"]].copy()
positive_pairs
# Out:
#                                              customer_id   age     month_sin  \
# 0      105f4c9f7ac528b9440bb3126f4ac2cce18992121f5f71...  35.0 -5.000000e-01
# 1      105f4c9f7ac528b9440bb3126f4ac2cce18992121f5f71...  35.0 -1.000000e+00
# 2      105f4c9f7ac528b9440bb3126f4ac2cce18992121f5f71...  35.0 -1.000000e+00
# 3      105f4c9f7ac528b9440bb3126f4ac2cce18992121f5f71...  35.0 -1.000000e+00
# 4      105f4c9f7ac528b9440bb3126f4ac2cce18992121f5f71...  35.0 -8.660254e-01
# ...                                                  ...   ...           ...
# 52516  f57a3de3dbcfc1f4026f06c36b5e1d9802a85f3503a59b...  23.0  0.000000e+00
# 52517  f57a3de3dbcfc1f4026f06c36b5e1d9802a85f3503a59b...  23.0 -5.000000e-01
# 52518  f6eeaa81b9dff0256beb2b1c31268626ae7ecb7669788f...  26.0 -8.660254e-01
# 52519  f6eeaa81b9dff0256beb2b1c31268626ae7ecb7669788f...  26.0  5.000000e-01
# 52520  fb90ddf5c8c9fdb3dde6cd9c073edc037c770ec80e4ea4...  43.0  1.224647e-16
#
#           month_cos article_id
# 0      8.660254e-01  179123001
# 1     -1.836970e-16  617835003
# 2     -1.836970e-16  622444003
# 3     -1.836970e-16  653567001
# 4      5.000000e-01  672491002
# ...             ...        ...
# 52516  1.000000e+00  507909001
# 52517 -8.660254e-01  711823004
# 52518  5.000000e-01  630116001
# 52519 -8.660254e-01  829643001
# 52520 -1.000000e+00  743644002
#
# [52521 rows x 5 columns]

# %%
n_neg = len(positive_pairs)*10

negative_pairs = positive_pairs[query_features]\
    .sample(n_neg, replace=True, random_state=1)\
    .reset_index(drop=True)

negative_pairs["article_id"] = positive_pairs["article_id"]\
    .sample(n_neg, replace=True, random_state=2).to_numpy()

negative_pairs
# Out:
#                                               customer_id   age     month_sin  \
# 0       950d0078a50b4174aad1270c475b2ad0e0e149dc767d27...  63.0 -8.660254e-01
# 1       a61e6bc03fa00146e2940b728dd331c36df956a485d747...  57.0  5.000000e-01
# 2       654ccec13aeb2316ff6a615fa629cd606094a766b98022...  50.0 -1.000000e+00
# 3       28a6df5f0cce682959b1cb23dc0958761dd3d470cc9706...  45.0 -1.000000e+00
# 4       8fab1eb72edc2c7ba438eb7051871e81cbb6344391d557...  46.0  1.224647e-16
# ...                                                   ...   ...           ...
# 525205  ee87369883b00e0b94b43cc240c2f5574d31e1124eb021...  27.0  0.000000e+00
# 525206  66785d1aeb70927d8cd69d766f3d787a19cf771965876d...  45.0  5.000000e-01
# 525207  0c44b5697c84f49c39712df9b5452ec131cf6cf4090e35...  34.0 -5.000000e-01
# 525208  9186f3dbc99115d92c82e78e455f928f54abaa2b08cde5...  39.0  1.224647e-16
# 525209  7d347408ed225f61f9e02e49389ba9a8d553155127e8ff...  25.0 -1.000000e+00
#
#            month_cos article_id
# 0       5.000000e-01  687704022
# 1      -8.660254e-01  843805003
# 2      -1.836970e-16  863001001
# 3      -1.836970e-16  547780004
# 4      -1.000000e+00  928210002
# ...              ...        ...
# 525205  1.000000e+00  879781002
# 525206 -8.660254e-01  711982001
# 525207 -8.660254e-01  856109001
# 525208 -1.000000e+00  442915014
# 525209 -1.836970e-16  366686001
#
# [525210 rows x 5 columns]

# %%
import pandas as pd

# Add labels.
positive_pairs["label"] = 1
negative_pairs["label"] = 0

# Concatenate.
ranking_df = pd.concat([positive_pairs, negative_pairs], ignore_index=True)
ranking_df.head()
# Out:
#                                          customer_id   age  month_sin  \
# 0  105f4c9f7ac528b9440bb3126f4ac2cce18992121f5f71...  35.0  -0.500000
# 1  105f4c9f7ac528b9440bb3126f4ac2cce18992121f5f71...  35.0  -1.000000
# 2  105f4c9f7ac528b9440bb3126f4ac2cce18992121f5f71...  35.0  -1.000000
# 3  105f4c9f7ac528b9440bb3126f4ac2cce18992121f5f71...  35.0  -1.000000
# 4  105f4c9f7ac528b9440bb3126f4ac2cce18992121f5f71...  35.0  -0.866025
#
#       month_cos article_id  label
# 0  8.660254e-01  179123001      1
# 1 -1.836970e-16  617835003      1
# 2 -1.836970e-16  622444003      1
# 3 -1.836970e-16  653567001      1
# 4  5.000000e-01  672491002      1

# %%
# Merge with item features.
articles_fg = fs.get_feature_group("articles")
item_df = articles_fg.read()
item_df.drop_duplicates(subset="article_id", inplace=True)
ranking_df = ranking_df.merge(item_df, on="article_id")
# Out:
# VersionWarning: No version provided for getting feature group `articles`, defaulting to `1`.
# 2022-11-15 11:04:13,866 INFO: USE `recsys_featurestore`
# 2022-11-15 11:04:14,820 INFO: SELECT `fg0`.`article_id` `article_id`, `fg0`.`product_code` `product_code`, `fg0`.`prod_name` `prod_name`, `fg0`.`product_type_no` `product_type_no`, `fg0`.`product_type_name` `product_type_name`, `fg0`.`product_group_name` `product_group_name`, `fg0`.`graphical_appearance_no` `graphical_appearance_no`, `fg0`.`graphical_appearance_name` `graphical_appearance_name`, `fg0`.`colour_group_code` `colour_group_code`, `fg0`.`colour_group_name` `colour_group_name`, `fg0`.`perceived_colour_value_id` `perceived_colour_value_id`, `fg0`.`perceived_colour_value_name` `perceived_colour_value_name`, `fg0`.`perceived_colour_master_id` `perceived_colour_master_id`, `fg0`.`perceived_colour_master_name` `perceived_colour_master_name`, `fg0`.`department_no` `department_no`, `fg0`.`department_name` `department_name`, `fg0`.`index_code` `index_code`, `fg0`.`index_name` `index_name`, `fg0`.`index_group_no` `index_group_no`, `fg0`.`index_group_name` `index_group_name`, `fg0`.`section_no` `section_no`, `fg0`.`section_name` `section_name`, `fg0`.`garment_group_no` `garment_group_no`, `fg0`.`garment_group_name` `garment_group_name`
# FROM `recsys_featurestore`.`articles_1` `fg0`
# UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy

# %% [markdown]
# Next, we compute the query and candidate embeddings.

# %% [markdown]
# There are several "duplicated" categorical features in the dataset. For instance, `index_code` and `index_name` encodes the same feature, but in different formats (int, string). Therefore we have to deduplicate these features.

# %%
def exclude_feat(s):
    return s.endswith("_id") or s.endswith("_no") or s.endswith("_code")

features_to_exclude = [col for col in ranking_df.columns if exclude_feat(col)]
features_to_exclude.append("prod_name")

ranking_df.drop(features_to_exclude, axis="columns", inplace=True)
ranking_df.head()
# Out:
#     age  month_sin     month_cos  label product_type_name  product_group_name  \
# 0  35.0  -0.500000  8.660254e-01      1   Leggings/Tights  Garment Lower body
# 1  33.0  -0.866025  5.000000e-01      1   Leggings/Tights  Garment Lower body
# 2  64.0  -1.000000 -1.836970e-16      1   Leggings/Tights  Garment Lower body
# 3  54.0   0.866025  5.000000e-01      1   Leggings/Tights  Garment Lower body
# 4  33.0  -0.500000  8.660254e-01      1   Leggings/Tights  Garment Lower body
#
#   graphical_appearance_name colour_group_name perceived_colour_value_name  \
# 0                     Solid             Black                        Dark
# 1                     Solid             Black                        Dark
# 2                     Solid             Black                        Dark
# 3                     Solid             Black                        Dark
# 4                     Solid             Black                        Dark
#
#   perceived_colour_master_name department_name  index_name index_group_name  \
# 0                        Black    Jersey Basic  Ladieswear       Ladieswear
# 1                        Black    Jersey Basic  Ladieswear       Ladieswear
# 2                        Black    Jersey Basic  Ladieswear       Ladieswear
# 3                        Black    Jersey Basic  Ladieswear       Ladieswear
# 4                        Black    Jersey Basic  Ladieswear       Ladieswear
#
#              section_name garment_group_name
# 0  Womens Everyday Basics       Jersey Basic
# 1  Womens Everyday Basics       Jersey Basic
# 2  Womens Everyday Basics       Jersey Basic
# 3  Womens Everyday Basics       Jersey Basic
# 4  Womens Everyday Basics       Jersey Basic

# %%
ranking_df.to_csv(ds_name, index=False)

# %%
dataset_api = project.get_dataset_api()
uploaded_file_path = dataset_api.upload(ds_name, "Resources", overwrite=True)
# Out:
# Uploading: 0.000%|          | 0/83896790 elapsed<00:00 remaining<?

# %% [markdown]
# ### Next Steps
#
# In the next notebook, we'll train a ranking model on the dataset we created in this notebook.
